# %%
! git clone https://github.com/AI4Finance-Foundation/FinNLP.git
# Out:
# Cloning into 'FinNLP'...
# remote: Enumerating objects: 1319, done.
# remote: Counting objects: 100% (378/378), done.
# remote: Compressing objects: 100% (138/138), done.
# remote: Total 1319 (delta 221), reused 357 (delta 206), pack-reused 941
# Receiving objects: 100% (1319/1319), 4.24 MiB | 8.82 MiB/s, done.
# Resolving deltas: 100% (594/594), done.

# %%
# !pip install -r FinNLP/requirements.txt
# !pip install parsel
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 6.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.1/131.1 kB 8.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 14.6 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 23.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 62.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.9/137.9 kB 18.2 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.9/200.9 kB 25.2 MB/s eta 0:00:00
# ...
#   Created wheel for jsonpath: filename=jsonpath-0.82.2-py3-none-any.whl size=5616 sha256=daa8fd1bc8781cfee9641ae7d32df4cc2323b35cba84c6786e26a2b9ad2ebd85
#   Stored in directory: /root/.cache/pip/wheels/a2/e3/6a/59f241672f3221253b1236359b0a711dabb69795a006184398
# ...

# %%
import sys
sys.path.append("../../FinNLP")
sys.path.append("../FinNLP")
sys.path.append("FinNLP")

# %%
# !ls FinNLP
# Out:
# Astock	demo  docs  finnlp  LICENSE  markdowns	README.md  requirements.txt  stocknet-dataset  test

# %%
news_downloader = CNBC_Streaming()
news_downloader.download_streaming_search(keyword = "apple", rounds = 30)

# %%
news_downloader.dataframe.shape
# Out:
# (300, 30)

# %%
news_downloader.dataframe
# Out:
#                                           description  \
# 0   Global smartphone sales rose in October after ...
# 1   Asian stock markets may have had a weak year, ...
# 2   One part of artificial intelligence will have ...
# 3   LOS ANGELES – Apple Original Films is a new pl...
# 4   Honor, a spinoff of Chinese technology giant H...
# ..                                                ...
# 5   This report is from today's CNBC Daily Open, o...
# 6   Traders braced for a big week filled with a Fe...
# 7   Here's our Club Mailbag email investingclubmai...
# 8   When 16-year-old Riley Galfi met an artist she...
# 9   Don't expect the earnings season to slow down ...
#
#               cn:lastPubDate              dateModified cn:dateline  \
# 0   2023-11-23T01:54:40+0000  2023-11-23T01:54:40+0000
# 1   2023-11-22T19:12:43+0000  2023-11-22T19:12:43+0000
# 2   2023-11-22T23:11:15+0000  2023-11-22T23:11:15+0000
# 3   2023-11-22T15:06:51+0000  2023-11-22T15:06:51+0000
# ...

# %%
selected_columns = ["datePublished", "cn:lastPubDate", "dateModified", "description", "section" ,"author", "summary" , "cn:title", "cn:type"]
dset = news_downloader.dataframe[selected_columns].head(1000)

# %%
dset
# Out:
#                datePublished            cn:lastPubDate  \
# 0   2023-11-23T03:29:16+0000  2023-11-23T01:54:40+0000
# 1   2023-11-23T00:12:43+0000  2023-11-22T19:12:43+0000
# 2   2023-11-23T00:09:41+0000  2023-11-22T23:11:15+0000
# 3   2023-11-22T20:06:51+0000  2023-11-22T15:06:51+0000
# 4   2023-11-22T17:15:21+0000  2023-11-22T21:53:16+0000
# ..                       ...                       ...
# 5   2023-10-30T00:03:11+0000  2023-10-29T20:03:11+0000
# 6   2023-10-29T22:33:54+0000  2023-10-30T17:00:28+0000
# 7   2023-10-29T14:34:17+0000  2023-10-30T15:19:22+0000
# 8   2023-10-29T13:00:01+0000  2023-10-29T09:00:01+0000
# 9   2023-10-29T10:41:48+0000  2023-11-03T17:06:55+0000
#
#                 dateModified  \
# 0   2023-11-23T01:54:40+0000
# 1   2023-11-22T19:12:43+0000
# 2   2023-11-22T23:11:15+0000
# 3   2023-11-22T15:06:51+0000
# 4   2023-11-22T21:53:16+0000
# ..                       ...
# 5   2023-10-29T20:03:11+0000
# 6   2023-10-30T17:00:28+0000
# ...

# %%
dset['datePublished'].min()
# Out:
# '2023-10-29T10:41:48+0000'

# %%
dset['datePublished'].str[:10].value_counts().sort_index()
# Out:
# 2023-10-29     4
# 2023-10-30    21
# 2023-10-31    11
# 2023-11-01    11
# 2023-11-02    21
# 2023-11-03    30
# 2023-11-04     2
# 2023-11-06    11
# 2023-11-07    21
# 2023-11-08    22
# 2023-11-09    35
# 2023-11-10    13
# 2023-11-11     1
# 2023-11-12     4
# 2023-11-13    13
# 2023-11-14    12
# 2023-11-15     9
# 2023-11-16    11
# 2023-11-17     7
# 2023-11-18     6
# 2023-11-19     5
# 2023-11-20     7
# 2023-11-21    13
# 2023-11-22     7
# 2023-11-23     3
# Name: datePublished, dtype: int64

# %%
dset['datePublished'].str[:10].hist()
# Out:
# <Axes: >
