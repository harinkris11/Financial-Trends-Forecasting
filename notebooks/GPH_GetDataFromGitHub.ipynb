# %%
# !git clone https://github.com/yumoxu/stocknet-dataset.git
# Out:
# Cloning into 'stocknet-dataset'...
# remote: Enumerating objects: 53785, done.
# remote: Total 53785 (delta 0), reused 0 (delta 0), pack-reused 53785
# Receiving objects: 100% (53785/53785), 66.95 MiB | 9.56 MiB/s, done.
# Resolving deltas: 100% (28658/28658), done.
# Updating files: 100% (55141/55141), done.

# %%
from google.colab import drive

# Mount your Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

# %%
PATH_PROJECT = '''/content/drive/MyDrive/UCSD/02_Courses_UCSD/04_Fall_Term_2023/01_Advanced_Data_Mining/DSC_250_PROJECT'''
PATH_DATA = os.path.join(PATH_PROJECT, 'datasets')

# %%
# !mv -r stocknet-dataset/price $PATH_DATA/price

# %%
# !mv -r stocknet-dataset/tweet $PATH_DATA/tweet
