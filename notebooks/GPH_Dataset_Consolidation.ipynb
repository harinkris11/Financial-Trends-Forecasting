# %%
import pandas as pd
import numpy as np
import os
import json

from tqdm import tqdm

# %%
from google.colab import drive

# Mount your Google Drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
PATH_PROJECT = '''/content/drive/MyDrive/UCSD/02_Courses_UCSD/04_Fall_Term_2023/01_Advanced_Data_Mining/DSC_250_PROJECT'''
PATH_DATA = os.path.join(PATH_PROJECT, 'datasets')

aggregated_folder = 'AGGREGATED_DATA'
PATH_AGG_DATA = os.path.join(PATH_DATA, aggregated_folder)

# %% [markdown]
# #### Consolidating Financial Data

# %%
PATH_PRICE_DATA = os.path.join(PATH_DATA, 'price/raw')

# %%
stock_data_files = [file for file in os.listdir(PATH_PRICE_DATA) if '.csv' in file]

# %%
stock_data_all = pd.DataFrame()
for file_name in tqdm(stock_data_files, position=0):
    ticker = file_name.split('.')[0]
    file_data = pd.read_csv(os.path.join(PATH_PRICE_DATA, file_name))
    file_data['ticker'] = ticker
    # Aggregating all the datasets
    stock_data_all = pd.concat([stock_data_all, file_data], axis=0)

# %%
stock_data_all.columns = [x.lower() for x in stock_data_all.columns]

# %%
# Storing the data in the Aggregated Directory
stock_data_all.to_csv(os.path.join(PATH_AGG_DATA, 'financial_data.csv'), index=False)

# %%
# Reading the data again from the Aggregated Directory
stock_data_all = pd.read_csv(os.path.join(PATH_AGG_DATA, 'financial_data.csv'))

# %% [markdown]
# ## Adding Tweet Vectors

# %%
# Reading Tweet data
tweets = pd.read_csv(os.path.join(PATH_AGG_DATA, 'tweet_embeddings_all_agg.csv'))

# %%
tweets.head()
# Out:
#   ticker        date  tp_0  tp_1  tp_2  tp_3  tp_4  tp_5  tp_6  tp_7  ...  \
# 0   AAPL  2013-12-31     1     0     0     0     0     0     0     0  ...
# 1   AAPL  2014-01-01     8     0     0     0     0     0     0     0  ...
# 2   AAPL  2014-01-02    31     0     0     0     0     0     0     0  ...
# 3   AAPL  2014-01-03    21     0     0     0     0     0     0     0  ...
# 4   AAPL  2014-01-04     5     0     0     0     0     0     0     0  ...
#
#    t2ve_503  t2ve_504  t2ve_505  t2ve_506  t2ve_507  t2ve_508  t2ve_509  \
# 0  0.024533  0.045217  0.082425 -0.009038  0.024683  0.014230 -0.005057
# 1  0.021426  0.034109  0.057758 -0.006272  0.038048  0.028415 -0.003747
# 2 -0.007182  0.042413  0.045770  0.003726  0.038268  0.026364 -0.009559
# 3  0.006636  0.038112  0.044563  0.007831  0.034383  0.044858 -0.010264
# 4 -0.002843  0.016980  0.058355 -0.014244  0.015553  0.025035 -0.018254
#
#    t2ve_510  t2ve_511  t2ve_512
# 0  0.036838 -0.034250  0.042868
# 1  0.028702 -0.046322  0.019313
# 2  0.031142 -0.054542 -0.013422
# 3  0.029918 -0.045999  0.008392
# 4  0.044570 -0.054826  0.017356
#
# [5 rows x 569 columns]

# %% [markdown]
# ### Merging Financial and Tweets Vectors

# %%
fin_tickers = stock_data_all['ticker'].drop_duplicates().to_list()
twe_tickers = tweets['ticker'].drop_duplicates().to_list()
[x for x in fin_tickers if x not in twe_tickers]
# Out:
# ['GMRE']

# %%
# Out:
# ['GMRE']

# %%
stock_data_merged = stock_data_all.merge(tweets, on=['date', 'ticker'], how='left')

# %%
# Storing the data (financial + tweets) in the Aggregated Directory
stock_data_merged.to_csv(os.path.join(PATH_AGG_DATA, 'financial_tweets_data.csv'), index=False)

# %%
# Reading the data again from the Aggregated Directory (Financial + Tweets)
stock_data_merged = pd.read_csv(os.path.join(PATH_AGG_DATA, 'financial_tweets_data.csv'))

# %%
stock_data_merged.isnull().mean()
# Out:
# date        0.000000
# open        0.000028
# high        0.000028
# low         0.000028
# close       0.000028
#               ...
# t2ve_508    0.798024
# t2ve_509    0.798024
# t2ve_510    0.798024
# t2ve_511    0.798024
# t2ve_512    0.798024
# Length: 575, dtype: float64

# %% [markdown]
# ## Adding News Vectors

# %%
os.path.join(PATH_AGG_DATA, 'financial_tweets_data.csv')
# Out:
# '/content/drive/MyDrive/UCSD/02_Courses_UCSD/04_Fall_Term_2023/01_Advanced_Data_Mining/DSC_250_PROJECT/datasets/AGGREGATED_DATA/financial_tweets_data.csv'

# %%
ls /content/drive/MyDrive/DSC250_project/DSC_250_PROJECT/datasets/AGGREGATED_DATA/
# Out:
# financial_data.csv         news.csv     news_upd.csv     tweet_embeddings_all_agg.csv
# financial_tweets_data.csv  news.gsheet  news_upd.gsheet

# %%
fintweet = os.path.join('/content/drive/MyDrive/DSC250_project/DSC_250_PROJECT/datasets/AGGREGATED_DATA/','financial_tweets_data.csv')

# %%
fintweetdf = pd.read_csv(fintweet)

# %%
# fintweetdf[fintweetdf['t2ve_503'].notna()]

# %%
newspath = os.path.join('/content/drive/MyDrive/DSC250_project/DSC_250_PROJECT/datasets/AGGREGATED_DATA/','news_upd.csv')

# %%
newsdf = pd.read_csv(newspath, encoding='latin-1', parse_dates= [1], lineterminator='\n')

# %%
newsdf['Date'] = pd.to_datetime(newsdf['Date'], errors='coerce')

# %%
newsdf
# Out:
#             Date                                              Title  \
# 0     2011-07-07  SPECIAL REPORT-Malaysia's dilemma: Can it refo...
# 1     2011-07-08  Special Report: Can Malaysia reform and discri...
# 2     2011-07-13  Danielle Chiesi settles SEC insider trading ca...
# 3     2011-07-18  UPDATE 5-IBM's services signings surge, stock ...
# 4     2011-07-19  Wall Street up on profits, Apple surges late,U...
# ...          ...                                                ...
# 17675 2017-07-19  Activist Jana cashes out of Whole Foods follow...
# 17676 2017-07-14  U.S. lawmaker calls for hearing on Amazon's Wh...
# 17677 2017-06-24  Even with Whole Foods, Amazon would need many ...
# 17678 2017-06-29  UPDATE 2-Nike to launch pilot program with Ama...
# 17679 2017-06-23  Even with Whole Foods, Amazon would need many ...
#
#                                                     Body ticker  \
# 0       putrajaya, malaysia, july 7 dr. mahathir moha...      T
# 1      putrajaya, malaysia dr. mahathir mohamad sits ...      T
# 2      new york danielle chiesi, a former trader who ...      T
# 3       * sets positive tone for tech earns, corporat...      T
# 4      new york stocks recorded their best day since ...      T
# ...                                                  ...    ...
# 17675  activist investor jana partners llc cashed out...   AMZN
# 17676  washington/new york the top democrat on the u....   AMZN
# 17677  if amazon.com inc  hopes to revolutionize groc...   AMZN
# 17678  * shares up 8.2 pct at $57.54 in after-market ...   AMZN
# 17679  june 23 if amazon.com inc hopes to\rrevolution...   AMZN
#
#                                          tokenized_words  \
# 0      ['putrajaya', ',', 'malaysia', ',', 'july', '7...
# 1      ['putrajaya', ',', 'malaysia', 'dr.', 'mahathi...
# 2      ['new', 'york', 'danielle', 'chiesi', ',', 'a'...
# 3      ['*', 'sets', 'positive', 'tone', 'for', 'tech...
# 4      ['new', 'york', 'stocks', 'recorded', 'their',...
# ...                                                  ...
# 17675  ['activist', 'investor', 'jana', 'partners', '...
# 17676  ['washington/new', 'york', 'the', 'top', 'demo...
# 17677  ['if', 'amazon.com', 'inc', 'hopes', 'to', 're...
# 17678  ['*', 'shares', 'up', '8.2', 'pct', 'at', '$',...
# 17679  ['june', '23', 'if', 'amazon.com', 'inc', 'hop...
#
#                                             cleaned_text  \
# 0      ['putrajaya', 'malaysia', 'july', '7', 'mahath...
# 1      ['putrajaya', 'malaysia', 'mahathir', 'mohamad...
# 2      ['new', 'york', 'danielle', 'chiesi', 'former'...
# 3      ['sets', 'positive', 'tone', 'tech', 'earns', ...
# 4      ['new', 'york', 'stocks', 'recorded', 'best', ...
# ...                                                  ...
# 17675  ['activist', 'investor', 'jana', 'partners', '...
# 17676  ['york', 'top', 'democrat', 'house', 'represen...
# 17677  ['inc', 'hopes', 'revolutionize', 'grocery', '...
# 17678  ['shares', 'pct', 'trade', 'adds', 'details', ...
# 17679  ['june', '23', 'inc', 'hopes', 'revolutionize'...
#
#       Title sentiment_label  Title sentiment_score  \
# 0                  NEGATIVE               0.993214
# 1                  NEGATIVE               0.987828
# 2                  POSITIVE               0.923182
# 3                  NEGATIVE               0.997758
# 4                  NEGATIVE               0.980940
# ...                     ...                    ...
# 17675              NEGATIVE               0.976309
# 17676              NEGATIVE               0.991219
# 17677              NEGATIVE               0.999077
# 17678              NEGATIVE               0.998893
# 17679              NEGATIVE               0.998184
#
#                                               newsVector
# 0      [-4.31280017e-01 -4.49921563e-02  3.54213178e-...
# 1      [-0.19804451  0.0515668   0.3471907   0.451883...
# 2      [-0.46932358  1.1376562  -0.36117563  1.298507...
# 3      [ 0.26701182 -0.8121374  -0.35769838  0.968121...
# 4      [ 1.6810181  -0.8761942  -1.6215013   1.167018...
# ...                                                  ...
# 17675  [ 2.8787196   0.47986117 -0.47300547 -1.054337...
# 17676  [ 0.26377246 -1.0956086  -1.2374927  -1.706804...
# 17677  [ 1.1441845e+00  4.1975534e-01 -1.4262140e-01 ...
# 17678  [-1.46899009e+00 -1.12892054e-01  2.65835994e-...
# 17679  [ 0.56067514  0.70193255  0.20231985  0.174875...
#
# [17680 rows x 9 columns]

# %%
# np.unique(newsdf['Title sentiment_label'])

# %%
df_encoded = pd.get_dummies(newsdf, columns=['Title sentiment_label'])

# %%
# df_encoded['Title sentiment_score'].apply(lambda x: -x if df_encoded['Title sentiment_label_NEGATIVE'] == 1 else x)

# %%
df_encoded['Title sentiment_score'] = df_encoded.apply(lambda row: -row['Title sentiment_score'] if row['Title sentiment_label_NEGATIVE'] == 1 else row['Title sentiment_score'], axis=1)

# %%
# newsdf_agg = newsdf.groupby('Date', 'ticker').agg({'Title sentiment_label_NEGATIVE':'sum', 'Title sentiment_label_POSITIVE': 'sum','Title sentiment_score':mean,'newsVector':'mean'})

# %%
df_encoded= df_encoded[df_encoded['newsVector'].notna()]

# %%
# df_encoded = pd.concat([df_encoded, df_encoded['newsVector'].apply(pd.Series).add_prefix('newsVector_')], axis=1)
# df_encoded = df_encoded.drop(columns=['newsVector'])

# %%
# df_encoded.explode('newsVector')

# %%
df_encoded['newsVector']
# Out:
# 0        [-4.31280017e-01 -4.49921563e-02  3.54213178e-...
# 1        [-0.19804451  0.0515668   0.3471907   0.451883...
# 2        [-0.46932358  1.1376562  -0.36117563  1.298507...
# 3        [ 0.26701182 -0.8121374  -0.35769838  0.968121...
# 4        [ 1.6810181  -0.8761942  -1.6215013   1.167018...
#                                ...
# 17675    [ 2.8787196   0.47986117 -0.47300547 -1.054337...
# 17676    [ 0.26377246 -1.0956086  -1.2374927  -1.706804...
# 17677    [ 1.1441845e+00  4.1975534e-01 -1.4262140e-01 ...
# 17678    [-1.46899009e+00 -1.12892054e-01  2.65835994e-...
# 17679    [ 0.56067514  0.70193255  0.20231985  0.174875...
# Name: newsVector, Length: 17680, dtype: object

# %%
df_encoded['newsVector'] = df_encoded['newsVector'].str.replace(r'\[ ', '[').str.replace('\n', ' ').str.replace(r'\s+', ',')
df_encoded['newsVector']
# Out:
# <ipython-input-261-c493f993bbb6>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_encoded['newsVector'] = df_encoded['newsVector'].str.replace(r'\[ ', '[').str.replace('\n', ' ').str.replace(r'\s+', ',')
# 0        [-4.31280017e-01,-4.49921563e-02,3.54213178e-0...
# 1        [-0.19804451,0.0515668,0.3471907,0.45188385,1....
# 2        [-0.46932358,1.1376562,-0.36117563,1.2985078,1...
# 3        [0.26701182,-0.8121374,-0.35769838,0.9681215,1...
# 4        [1.6810181,-0.8761942,-1.6215013,1.1670184,1.0...
#                                ...
# 17675    [2.8787196,0.47986117,-0.47300547,-1.054337,0....
# 17676    [0.26377246,-1.0956086,-1.2374927,-1.7068045,1...
# 17677    [1.1441845e+00,4.1975534e-01,-1.4262140e-01,-1...
# 17678    [-1.46899009e+00,-1.12892054e-01,2.65835994e-0...
# 17679    [0.56067514,0.70193255,0.20231985,0.17487547,1...
# Name: newsVector, Length: 17680, dtype: object

# %%
import ast
df_encoded['newsVector'].apply(ast.literal_eval)
# Out:
# 0        [-0.431280017, -0.0449921563, 0.354213178, 0.6...
# 1        [-0.19804451, 0.0515668, 0.3471907, 0.45188385...
# 2        [-0.46932358, 1.1376562, -0.36117563, 1.298507...
# 3        [0.26701182, -0.8121374, -0.35769838, 0.968121...
# 4        [1.6810181, -0.8761942, -1.6215013, 1.1670184,...
#                                ...
# 17675    [2.8787196, 0.47986117, -0.47300547, -1.054337...
# 17676    [0.26377246, -1.0956086, -1.2374927, -1.706804...
# 17677    [1.1441845, 0.41975534, -0.1426214, -0.1963934...
# 17678    [-1.46899009, -0.112892054, 0.00265835994, -1....
# 17679    [0.56067514, 0.70193255, 0.20231985, 0.1748754...
# Name: newsVector, Length: 17680, dtype: object

# %%
# df_encoded['newsVector'] = df_encoded['newsVector'].apply(ast.literal_eval)

# # Create separate columns for each element in the 'newsVector' arrays
# embedding = pd.DataFrame(df_encoded['newsVector'].to_list(), columns=[f'news2ve_{i+1:03d}' for i in range(128)])

# %%
df_encoded['newsVector'] = df_encoded['newsVector'].apply(ast.literal_eval)

# Create separate columns for each element in the 'newsVector' arrays
embedding = pd.DataFrame(df_encoded['newsVector'].to_list(), columns=[f'news2ve_{i+1:03d}' for i in range(128)])

# Concatenate the DataFrames along columns
df_encoded = pd.concat([df_encoded, embedding], axis=1)

# %%
df_encoded.drop('newsVector', inplace = True, axis = 1)

# %%
df_encoded.drop(['Body','Title', 'tokenized_words', 'cleaned_text'], inplace = True, axis =1)
df_encoded[:3]
# Out:
#         Date ticker  Title sentiment_score  Title sentiment_label_NEGATIVE  \
# 0 2011-07-07      T              -0.993214                               1
# 1 2011-07-08      T              -0.987828                               1
# 2 2011-07-13      T               0.923182                               0
#
#    Title sentiment_label_POSITIVE  news2ve_001  news2ve_002  news2ve_003  \
# 0                               0    -0.431280    -0.044992     0.354213
# 1                               0    -0.198045     0.051567     0.347191
# 2                               1    -0.469324     1.137656    -0.361176
#
#    news2ve_004  news2ve_005  ...  news2ve_119  news2ve_120  news2ve_121  \
# 0     0.697911     2.045450  ...     0.652926     0.672569     1.553473
# 1     0.451884     1.218303  ...     0.282431     0.532512     0.984212
# 2     1.298508     1.164419  ...    -0.490781    -1.114714     0.677273
#
#    news2ve_122  news2ve_123  news2ve_124  news2ve_125  news2ve_126  \
# 0     0.262625    -0.799215     1.546489     0.253900     0.593565
# 1     0.093855    -0.571536     1.049526     0.365417     0.412591
# 2     1.133146    -0.884837     1.651788     1.189902     0.965121
#
#    news2ve_127  news2ve_128
# 0    -1.572047     0.571509
# 1    -0.873022     0.345252
# 2    -0.288995     0.767504
#
# [3 rows x 133 columns]

# %%
sum_cols = ['Title sentiment_label_NEGATIVE', 'Title sentiment_label_POSITIVE']
agg_spec = {col: 'sum' if col in sum_cols else 'mean' for col in df_encoded.columns if col not in ['Date', 'ticker']}

result_df = df_encoded.groupby(['Date', 'ticker']).agg(agg_spec).reset_index()

# %%
result_df[~result_df['Title sentiment_label_NEGATIVE'].isin([0, 1])][:3]
# Out:
#          Date ticker  Title sentiment_score  Title sentiment_label_NEGATIVE  \
# 10 2011-07-07    CVX              -0.995630                               2
# 18 2011-07-07      T              -0.995630                               2
# 20 2011-07-07    WFC              -0.997364                               2
#
#     Title sentiment_label_POSITIVE  news2ve_001  news2ve_002  news2ve_003  \
# 10                               0    -0.449709    -0.058782    -0.639056
# 18                               0    -0.450152    -0.147789    -0.623698
# 20                               0    -0.459645    -1.063087    -0.789878
#
#     news2ve_004  news2ve_005  ...  news2ve_119  news2ve_120  news2ve_121  \
# 10     0.511857     1.384502  ...     0.156071     0.173405     1.604592
# 18     0.500802     1.374063  ...     0.251578     0.293472     1.779962
# 20     0.794720     1.180768  ...     0.051219     0.199608     1.569285
#
#     news2ve_122  news2ve_123  news2ve_124  news2ve_125  news2ve_126  \
# 10    -0.256845     0.126767     1.364651     0.185753     0.334969
# 18    -0.188921     0.002315     1.179925     0.213279     0.740445
# 20    -0.317709     0.399325     1.846466    -0.183971     0.052971
#
#     news2ve_127  news2ve_128
# 10    -0.906285     1.272592
# 18    -1.119182     1.100583
# 20    -1.141585     0.925457
#
# [3 rows x 133 columns]

# %%
result_df.rename(columns={"Title sentiment_score": "News_SScore", "Title sentiment_label_NEGATIVE": "NegSenCount_news", "Title sentiment_label_POSITIVE": "PosSenCount_news"}, inplace = True)

# %%
import datetime as dt
result_df['Day'] = result_df['Date'].dt.dayofweek

# %%
pwd
# Out:
# '/content'

# %%
result_df.to_csv('/content/drive/MyDrive/DSC250_project/DSC_250_PROJECT/datasets/AGGREGATED_DATA/news_final_agg.csv')

# %%
result_df.drop('Day', inplace = True, axis = 1)

# %%
weekend_mask = (result_df['Date'].dt.dayofweek == 5) | (result_df['Date'].dt.dayofweek == 6)
result_df.loc[weekend_mask, 'Date'] = result_df.loc[weekend_mask, 'Date'] - pd.to_timedelta((result_df.loc[weekend_mask, 'Date'].dt.dayofweek + 2) % 7, unit='d')

# %%
result_df[:3]
# Out:
#         Date     ticker  News_SScore  NegSenCount_news  PosSenCount_news  \
# 0 2011-07-06  005930.KS    -0.998924                 1                 0
# 1 2011-07-06       AAPL    -0.999012                 1                 0
# 2 2011-07-06     GOOG.O    -0.880484                 1                 0
#
#    news2ve_001  news2ve_002  news2ve_003  news2ve_004  news2ve_005  ...  \
# 0    -1.010626    -1.703238    -0.413511     0.389713     2.163167  ...
# 1    -0.157108    -0.571859     0.032514     0.166861     0.729311  ...
# 2    -0.856936     0.664619    -1.106251    -0.652251    -0.023104  ...
#
#    news2ve_119  news2ve_120  news2ve_121  news2ve_122  news2ve_123  \
# 0     0.207646     1.655146     0.889079     1.486760    -1.184951
# 1    -0.760558     0.543086     0.346933     0.051830    -0.204596
# 2     0.391603    -0.588558    -1.007424    -0.152823    -0.645491
#
#    news2ve_124  news2ve_125  news2ve_126  news2ve_127  news2ve_128
# 0    -0.201042     0.472570    -0.201521     1.017336    -0.113666
# 1     0.859705     0.747626    -0.776559     0.479887    -0.620001
# 2     0.437398     0.711479     1.316568    -0.006403     2.237492
#
# [3 rows x 133 columns]

# %%
sum_cols = ['NegSenCount_news', 'PosSenCount_news']
agg_spec = {col: 'sum' if col in sum_cols else 'mean' for col in result_df.columns if col not in ['Date', 'ticker']}

result_df = result_df.groupby(['Date', 'ticker']).agg(agg_spec).reset_index()

# %%
pd.to_datetime('2011-07-12') - pd.to_timedelta(2, unit='d')
# Out:
# Timestamp('2011-07-10 00:00:00')

# %%
# agg_spec
result_df[:3]
# Out:
#         Date     ticker  News_SScore  NegSenCount_news  PosSenCount_news  \
# 0 2011-07-06  005930.KS    -0.998924                 1                 0
# 1 2011-07-06       AAPL    -0.999012                 1                 0
# 2 2011-07-06     GOOG.O    -0.880484                 1                 0
#
#    news2ve_001  news2ve_002  news2ve_003  news2ve_004  news2ve_005  ...  \
# 0    -1.010626    -1.703238    -0.413511     0.389713     2.163167  ...
# 1    -0.157108    -0.571859     0.032514     0.166861     0.729311  ...
# 2    -0.856936     0.664619    -1.106251    -0.652251    -0.023104  ...
#
#    news2ve_119  news2ve_120  news2ve_121  news2ve_122  news2ve_123  \
# 0     0.207646     1.655146     0.889079     1.486760    -1.184951
# 1    -0.760558     0.543086     0.346933     0.051830    -0.204596
# 2     0.391603    -0.588558    -1.007424    -0.152823    -0.645491
#
#    news2ve_124  news2ve_125  news2ve_126  news2ve_127  news2ve_128
# 0    -0.201042     0.472570    -0.201521     1.017336    -0.113666
# 1     0.859705     0.747626    -0.776559     0.479887    -0.620001
# 2     0.437398     0.711479     1.316568    -0.006403     2.237492
#
# [3 rows x 133 columns]

# %%
result_df[result_df['Date']=='2011-07-09']
# Out:
#          Date  ticker  News_SScore  NegSenCount_news  PosSenCount_news  \
# 35 2011-07-09  GOOG.O    -0.993750                 1                 0
# 36 2011-07-09    MSFT    -0.975574                 1                 0
# 37 2011-07-09     WFC    -0.997016                 1                 0
# 38 2011-07-09     WMT    -0.997016                 1                 0
# 39 2011-07-09     XOM    -0.986899                 1                 0
# 40 2011-07-09  GOOG.O     0.997549                 0                 1
# 41 2011-07-09     SNE     0.998013                 0                 1
# 42 2011-07-09     WFC    -0.999193                 1                 0
# 43 2011-07-09     WMT    -0.999193                 1                 0
# 44 2011-07-09     XOM     0.743077                 0                 1
#
#     news2ve_001  news2ve_002  news2ve_003  news2ve_004  news2ve_005  ...  \
# 35     0.074114    -1.434250     0.393718    -0.382882    -0.344560  ...
# 36    -0.944030    -1.163441     0.403251     0.927118    -0.199482  ...
# 37    -0.513324     0.488187    -0.444872     0.149936     1.965795  ...
# 38    -0.299365     0.607652    -0.516626     0.366252     1.787261  ...
# 39     2.125535    -1.308712    -0.182609    -0.073314     3.261914  ...
# 40     0.121043    -1.272155     1.259052    -1.098615    -0.087348  ...
# 41     1.349513    -0.647289    -1.199408     1.655642     2.480747  ...
# 42     0.527875    -1.076852    -1.091059    -0.344906     0.599533  ...
# 43     0.486509    -1.044712    -0.951296    -0.553122     0.457180  ...
# 44     1.307279    -0.900849    -0.177552     0.286420     1.010895  ...
#
#     news2ve_119  news2ve_120  news2ve_121  news2ve_122  news2ve_123  \
# 35    -0.145133     1.002738     1.032894    -0.351467    -0.227782
# 36     1.039433     0.062991     0.650166     1.076942    -0.760517
# 37     0.816621     0.424943     0.096163    -0.573076    -0.873368
# 38     0.737390     0.097007     0.074738    -0.380683    -0.778668
# 39    -0.233849     1.485784    -0.685938     0.849161    -3.926746
# 40    -0.430775     0.353442     0.752615    -0.186525    -1.012268
# 41     0.663139     1.054932     2.737459     0.263174    -1.671819
# 42    -0.162097     1.178586     0.661078    -0.468704    -0.740535
# 43    -0.202617     0.944761     0.619674    -0.670443    -0.553915
# 44     0.482052     0.938210     0.514401    -0.747438    -1.997041
#
#     news2ve_124  news2ve_125  news2ve_126  news2ve_127  news2ve_128
# 35     0.358869     0.731445     0.239168     1.762773     1.043558
# 36     1.099971    -0.254094    -1.026519    -0.569805    -0.970371
# 37     0.165905    -0.352631    -0.015000     1.161511     0.817149
# 38     0.485035    -0.390900    -0.039776     1.104684     0.823243
# 39    -0.280761    -2.077832    -1.530151     0.228261     1.020479
# 40     0.498293     0.530837     0.806912     2.979025     2.057071
# 41     0.166997    -1.157910    -1.553723    -0.262906     0.461717
# 42     0.163233    -0.560348    -0.219111    -0.113235     0.100567
# 43     0.204401    -0.455772    -0.318683    -0.213919     0.110243
# 44     2.121648    -0.467750    -1.027770    -1.017986     0.292294
#
# [10 rows x 133 columns]

# %%
# df_encoded['newsVector'] = df_encoded['newsVector'].apply(lambda x: pd.to_numeric(x, errors='coerce'))

# columns_to_aggregate = ['Title sentiment_label_NEGATIVE', 'Title sentiment_label_POSITIVE', 'Title sentiment_score', 'newsVector']
# grouped_df = df_encoded.groupby(['Date', 'ticker'])[columns_to_aggregate].agg({
#     'Title sentiment_label_NEGATIVE': 'sum',
#     'Title sentiment_label_POSITIVE': 'sum',
#     'Title sentiment_score': np.mean,
#     'newsVector': np.mean
# }).reset_index()

# %%
grouped_df[grouped_df['newsVector'].notna()]
# Out:
# Empty DataFrame
# Columns: [Date, ticker, Title sentiment_label_NEGATIVE, Title sentiment_label_POSITIVE, Title sentiment_score, newsVector]
# Index: []

# %%
df_encoded
# Out:
#             Date                                              Title  \
# 0     2011-07-07  SPECIAL REPORT-Malaysia's dilemma: Can it refo...
# 1     2011-07-08  Special Report: Can Malaysia reform and discri...
# 2     2011-07-13  Danielle Chiesi settles SEC insider trading ca...
# 3     2011-07-18  UPDATE 5-IBM's services signings surge, stock ...
# 4     2011-07-19  Wall Street up on profits, Apple surges late,U...
# ...          ...                                                ...
# 17675 2017-07-19  Activist Jana cashes out of Whole Foods follow...
# 17676 2017-07-14  U.S. lawmaker calls for hearing on Amazon's Wh...
# 17677 2017-06-24  Even with Whole Foods, Amazon would need many ...
# 17678 2017-06-29  UPDATE 2-Nike to launch pilot program with Ama...
# 17679 2017-06-23  Even with Whole Foods, Amazon would need many ...
#
#                                                     Body ticker  \
# 0       putrajaya, malaysia, july 7 dr. mahathir moha...      T
# 1      putrajaya, malaysia dr. mahathir mohamad sits ...      T
# 2      new york danielle chiesi, a former trader who ...      T
# 3       * sets positive tone for tech earns, corporat...      T
# 4      new york stocks recorded their best day since ...      T
# ...                                                  ...    ...
# 17675  activist investor jana partners llc cashed out...   AMZN
# 17676  washington/new york the top democrat on the u....   AMZN
# 17677  if amazon.com inc  hopes to revolutionize groc...   AMZN
# 17678  * shares up 8.2 pct at $57.54 in after-market ...   AMZN
# 17679  june 23 if amazon.com inc hopes to\rrevolution...   AMZN
#
#                                          tokenized_words  \
# 0      ['putrajaya', ',', 'malaysia', ',', 'july', '7...
# 1      ['putrajaya', ',', 'malaysia', 'dr.', 'mahathi...
# 2      ['new', 'york', 'danielle', 'chiesi', ',', 'a'...
# 3      ['*', 'sets', 'positive', 'tone', 'for', 'tech...
# 4      ['new', 'york', 'stocks', 'recorded', 'their',...
# ...                                                  ...
# 17675  ['activist', 'investor', 'jana', 'partners', '...
# 17676  ['washington/new', 'york', 'the', 'top', 'demo...
# 17677  ['if', 'amazon.com', 'inc', 'hopes', 'to', 're...
# 17678  ['*', 'shares', 'up', '8.2', 'pct', 'at', '$',...
# 17679  ['june', '23', 'if', 'amazon.com', 'inc', 'hop...
#
#                                             cleaned_text  \
# 0      ['putrajaya', 'malaysia', 'july', '7', 'mahath...
# 1      ['putrajaya', 'malaysia', 'mahathir', 'mohamad...
# 2      ['new', 'york', 'danielle', 'chiesi', 'former'...
# 3      ['sets', 'positive', 'tone', 'tech', 'earns', ...
# 4      ['new', 'york', 'stocks', 'recorded', 'best', ...
# ...                                                  ...
# 17675  ['activist', 'investor', 'jana', 'partners', '...
# 17676  ['york', 'top', 'democrat', 'house', 'represen...
# 17677  ['inc', 'hopes', 'revolutionize', 'grocery', '...
# 17678  ['shares', 'pct', 'trade', 'adds', 'details', ...
# 17679  ['june', '23', 'inc', 'hopes', 'revolutionize'...
#
#        Title sentiment_score  \
# 0                  -0.993214
# 1                  -0.987828
# 2                   0.923182
# 3                  -0.997758
# 4                  -0.980940
# ...                      ...
# 17675              -0.976309
# 17676              -0.991219
# 17677              -0.999077
# 17678              -0.998893
# 17679              -0.998184
#
#                                               newsVector  \
# 0      [-4.31280017e-01 -4.49921563e-02  3.54213178e-...
# 1      [-0.19804451  0.0515668   0.3471907   0.451883...
# 2      [-0.46932358  1.1376562  -0.36117563  1.298507...
# 3      [ 0.26701182 -0.8121374  -0.35769838  0.968121...
# 4      [ 1.6810181  -0.8761942  -1.6215013   1.167018...
# ...                                                  ...
# 17675  [ 2.8787196   0.47986117 -0.47300547 -1.054337...
# 17676  [ 0.26377246 -1.0956086  -1.2374927  -1.706804...
# 17677  [ 1.1441845e+00  4.1975534e-01 -1.4262140e-01 ...
# 17678  [-1.46899009e+00 -1.12892054e-01  2.65835994e-...
# 17679  [ 0.56067514  0.70193255  0.20231985  0.174875...
#
#        Title sentiment_label_NEGATIVE  Title sentiment_label_POSITIVE
# 0                                   1                               0
# 1                                   1                               0
# 2                                   0                               1
# 3                                   1                               0
# 4                                   1                               0
# ...                               ...                             ...
# 17675                               1                               0
# 17676                               1                               0
# 17677                               1                               0
# 17678                               1                               0
# 17679                               1                               0
#
# [17680 rows x 10 columns]

# %%
df_encoded[df_encoded['Title sentiment_score']]
# Out:
#             Date                                              Title  \
# 0     2011-07-07  SPECIAL REPORT-Malaysia's dilemma: Can it refo...
# 1     2011-07-08  Special Report: Can Malaysia reform and discri...
# 2     2011-07-13  Danielle Chiesi settles SEC insider trading ca...
# 3     2011-07-18  UPDATE 5-IBM's services signings surge, stock ...
# 4     2011-07-19  Wall Street up on profits, Apple surges late,U...
# ...          ...                                                ...
# 17675 2017-07-19  Activist Jana cashes out of Whole Foods follow...
# 17676 2017-07-14  U.S. lawmaker calls for hearing on Amazon's Wh...
# 17677 2017-06-24  Even with Whole Foods, Amazon would need many ...
# 17678 2017-06-29  UPDATE 2-Nike to launch pilot program with Ama...
# 17679 2017-06-23  Even with Whole Foods, Amazon would need many ...
#
#                                                     Body ticker  \
# 0       putrajaya, malaysia, july 7 dr. mahathir moha...      T
# 1      putrajaya, malaysia dr. mahathir mohamad sits ...      T
# 2      new york danielle chiesi, a former trader who ...      T
# 3       * sets positive tone for tech earns, corporat...      T
# 4      new york stocks recorded their best day since ...      T
# ...                                                  ...    ...
# 17675  activist investor jana partners llc cashed out...   AMZN
# 17676  washington/new york the top democrat on the u....   AMZN
# 17677  if amazon.com inc  hopes to revolutionize groc...   AMZN
# 17678  * shares up 8.2 pct at $57.54 in after-market ...   AMZN
# 17679  june 23 if amazon.com inc hopes to\rrevolution...   AMZN
#
#                                          tokenized_words  \
# 0      ['putrajaya', ',', 'malaysia', ',', 'july', '7...
# 1      ['putrajaya', ',', 'malaysia', 'dr.', 'mahathi...
# 2      ['new', 'york', 'danielle', 'chiesi', ',', 'a'...
# 3      ['*', 'sets', 'positive', 'tone', 'for', 'tech...
# 4      ['new', 'york', 'stocks', 'recorded', 'their',...
# ...                                                  ...
# 17675  ['activist', 'investor', 'jana', 'partners', '...
# 17676  ['washington/new', 'york', 'the', 'top', 'demo...
# 17677  ['if', 'amazon.com', 'inc', 'hopes', 'to', 're...
# 17678  ['*', 'shares', 'up', '8.2', 'pct', 'at', '$',...
# 17679  ['june', '23', 'if', 'amazon.com', 'inc', 'hop...
#
#                                             cleaned_text  \
# 0      ['putrajaya', 'malaysia', 'july', '7', 'mahath...
# 1      ['putrajaya', 'malaysia', 'mahathir', 'mohamad...
# 2      ['new', 'york', 'danielle', 'chiesi', 'former'...
# 3      ['sets', 'positive', 'tone', 'tech', 'earns', ...
# 4      ['new', 'york', 'stocks', 'recorded', 'best', ...
# ...                                                  ...
# 17675  ['activist', 'investor', 'jana', 'partners', '...
# 17676  ['york', 'top', 'democrat', 'house', 'represen...
# 17677  ['inc', 'hopes', 'revolutionize', 'grocery', '...
# 17678  ['shares', 'pct', 'trade', 'adds', 'details', ...
# 17679  ['june', '23', 'inc', 'hopes', 'revolutionize'...
#
#        Title sentiment_score  \
# 0                   0.993214
# 1                   0.987828
# 2                   0.923182
# 3                   0.997758
# 4                   0.980940
# ...                      ...
# 17675               0.976309
# 17676               0.991219
# 17677               0.999077
# 17678               0.998893
# 17679               0.998184
#
#                                               newsVector  \
# 0      [-4.31280017e-01 -4.49921563e-02  3.54213178e-...
# 1      [-0.19804451  0.0515668   0.3471907   0.451883...
# 2      [-0.46932358  1.1376562  -0.36117563  1.298507...
# 3      [ 0.26701182 -0.8121374  -0.35769838  0.968121...
# 4      [ 1.6810181  -0.8761942  -1.6215013   1.167018...
# ...                                                  ...
# 17675  [ 2.8787196   0.47986117 -0.47300547 -1.054337...
# 17676  [ 0.26377246 -1.0956086  -1.2374927  -1.706804...
# 17677  [ 1.1441845e+00  4.1975534e-01 -1.4262140e-01 ...
# 17678  [-1.46899009e+00 -1.12892054e-01  2.65835994e-...
# 17679  [ 0.56067514  0.70193255  0.20231985  0.174875...
#
#        Title sentiment_label_NEGATIVE  Title sentiment_label_POSITIVE
# 0                                   1                               0
# 1                                   1                               0
# 2                                   0                               1
# 3                                   1                               0
# 4                                   1                               0
# ...                               ...                             ...
# 17675                               1                               0
# 17676                               1                               0
# 17677                               1                               0
# 17678                               1                               0
# 17679                               1                               0
#
# [17680 rows x 10 columns]

# %%
newsdf[newsdf['Date']=='2011-07-12']
# Out:
#             Date                                              Title  \
# 18    2011-07-12  Obama holding lunch mtg with business execs on...
# 468   2011-07-12  Regulators combat unauthorized phone bill fees...
# 1124  2011-07-12  Electronic Arts buying PopCap Games for up to ...
# 2026  2011-07-12  UPDATE 1-Firestone wins Liberian child labor c...
# 2893  2011-07-12  Regulators combat unauthorized phone bill fees...
# 3395  2011-07-12  Apple chief patent lawyer leaving: sources,Tos...
# 4948  2011-07-12  Electronic Arts buying PopCap Games for up to ...
# 6608  2011-07-12  Regulators combat unauthorized phone bill fees...
# 7111  2011-07-12  Analysis: Wal-Mart ruling no knock-out blow fo...
# 7920  2011-07-12  BRIEF-Moody's Downgrades Wells Fargo's Service...
# 8640  2011-07-12  UPDATE 1-UAW hosting Big 3 this week on fuel s...
# 9595  2011-07-12  Obama holding lunch mtg with business execs on...
# 10113 2011-07-12  Obama holding lunch mtg with business execs on...
# 10563 2011-07-12  Regulators combat unauthorized phone bill fees...
# 11215 2011-07-12  UPDATE 1-Chevron says expect to start Liberia ...
# 11917 2011-07-12  Borders defends auction plan amid landlords' i...
# 12664 2011-07-12  Regulators combat unauthorized phone bill fees...
# 13167 2011-07-12  Analysis: Wal-Mart ruling no knock-out blow fo...
# 13977 2011-07-12  Google costs in focus after busy quarter,PREVI...
# 15647 2011-07-12  REFILE-UPDATE 1-Sony India sees sales growth s...
# 16710 2011-07-12  Netflix raises DVD, streaming plan price by 60...
#
#                                                     Body     ticker  \
# 18      washington, july 12 president barack obama wa...          T
# 468    washington telephone companies would have to m...          T
# 1124   new york electronic arts inc , the video game ...     GOOG.O
# 2026    * companies can be held liable for human-righ...        XOM
# 2893   washington telephone companies would have to m...         VZ
# 3395   san francisco apple inc's chief patent counsel...  005930.KS
# 4948   new york electronic arts inc , the video game ...       AAPL
# 6608   washington telephone companies would have to m...        WFC
# 7111   new york the end of the road for a class-actio...        WFC
# 7920   july 13, 2011 (reuters)--moody's downgrades we...        WFC
# 8640    * 56.2 miles per gallon being eyed as new sta...          F
# 9595    washington, july 12 president barack obama wa...        IBM
# 10113   washington, july 12 president barack obama wa...        CVX
# 10563  washington telephone companies would have to m...        CVX
# 11215   * neighbouring sierra leone has found oil\r\r...        CVX
# 11917  new york borders group inc  on tuesday answere...         GE
# 12664  washington telephone companies would have to m...        WMT
# 13167  new york the end of the road for a class-actio...        WMT
# 13977  san francisco google inc's investment spree an...       MSFT
# 15647   * expects inflation, interest rates to crimp ...        SNE
# 16710  los angeles netflix inc hiked monthly prices f...       AMZN
#
#                                          tokenized_words  \
# 18     ['washington', ',', 'july', '12', 'president',...
# 468    ['washington', 'telephone', 'companies', 'woul...
# 1124   ['new', 'york', 'electronic', 'arts', 'inc', '...
# 2026   ['*', 'companies', 'can', 'be', 'held', 'liabl...
# 2893   ['washington', 'telephone', 'companies', 'woul...
# 3395   ['san', 'francisco', 'apple', 'inc', "'s", 'ch...
# 4948   ['new', 'york', 'electronic', 'arts', 'inc', '...
# 6608   ['washington', 'telephone', 'companies', 'woul...
# 7111   ['new', 'york', 'the', 'end', 'of', 'the', 'ro...
# 7920   ['july', '13', ',', '2011', '(', 'reuters', ')...
# 8640   ['*', '56.2', 'miles', 'per', 'gallon', 'being...
# 9595   ['washington', ',', 'july', '12', 'president',...
# 10113  ['washington', ',', 'july', '12', 'president',...
# 10563  ['washington', 'telephone', 'companies', 'woul...
# 11215  ['*', 'neighbouring', 'sierra', 'leone', 'has'...
# 11917  ['new', 'york', 'borders', 'group', 'inc', 'on...
# 12664  ['washington', 'telephone', 'companies', 'woul...
# 13167  ['new', 'york', 'the', 'end', 'of', 'the', 'ro...
# 13977  ['san', 'francisco', 'google', 'inc', "'s", 'i...
# 15647  ['*', 'expects', 'inflation', ',', 'interest',...
# 16710  ['los', 'angeles', 'netflix', 'inc', 'hiked', ...
#
#                                             cleaned_text  \
# 18     ['washington', 'july', '12', 'president', 'bar...
# 468    ['washington', 'telephone', 'companies', 'woul...
# 1124   ['new', 'york', 'electronic', 'arts', 'inc', '...
# 2026   ['companies', 'held', 'liable', 'abuses', 'abr...
# 2893   ['washington', 'telephone', 'companies', 'woul...
# 3395   ['san', 'francisco', 'apple', 'inc', 'chief', ...
# 4948   ['new', 'york', 'electronic', 'arts', 'inc', '...
# 6608   ['washington', 'telephone', 'companies', 'woul...
# 7111   ['new', 'york', 'end', 'road', 'discrimination...
# 7920   ['july', '13', '2011', 'reuters', 'moody', 'do...
# 8640   ['miles', 'per', 'gallon', 'eyed', 'new', 'sta...
# 9595   ['washington', 'july', '12', 'president', 'bar...
# 10113  ['washington', 'july', '12', 'president', 'bar...
# 10563  ['washington', 'telephone', 'companies', 'woul...
# 11215  ['neighbouring', 'sierra', 'leone', 'found', '...
# 11917  ['new', 'york', 'borders', 'group', 'inc', 'tu...
# 12664  ['washington', 'telephone', 'companies', 'woul...
# 13167  ['new', 'york', 'end', 'road', 'discrimination...
# 13977  ['san', 'francisco', 'google', 'inc', 'investm...
# 15647  ['expects', 'inflation', 'interest', 'rates', ...
# 16710  ['los', 'angeles', 'netflix', 'inc', 'hiked', ...
#
#       Title sentiment_label  Title sentiment_score  \
# 18                 NEGATIVE               0.972524
# 468                NEGATIVE               0.983715
# 1124               NEGATIVE               0.999164
# 2026               POSITIVE               0.999353
# 2893               NEGATIVE               0.976724
# 3395               NEGATIVE               0.993491
# 4948               NEGATIVE               0.998376
# 6608               NEGATIVE               0.976724
# 7111               NEGATIVE               0.987345
# 7920               NEGATIVE               0.945500
# 8640               NEGATIVE               0.999400
# 9595               NEGATIVE               0.972524
# 10113              NEGATIVE               0.972524
# 10563              NEGATIVE               0.983715
# 11215              NEGATIVE               0.986557
# 11917              NEGATIVE               0.997277
# 12664              NEGATIVE               0.976724
# 13167              NEGATIVE               0.987345
# 13977              NEGATIVE               0.999534
# 15647              NEGATIVE               0.998411
# 16710              NEGATIVE               0.989713
#
#                                               newsVector
# 18     [-5.4592901e-01 -5.7942414e-01  2.1099211e-01 ...
# 468    [ 2.1390417   1.1236602  -2.027831    1.788465...
# 1124   [-0.37570712 -3.498245   -0.39497977  0.146711...
# 2026   [-2.1302390e+00  5.4395765e-02 -2.9384639e+00 ...
# 2893   [-6.2695724e-01  2.8825265e-01 -1.5188003e+00 ...
# 3395   [-1.9358366  -0.64709556 -0.0476862   1.592252...
# 4948   [-1.8747267  -2.0403597  -1.3048285   0.518847...
# 6608   [-0.63758945  0.5392483  -1.5211304  -1.144361...
# 7111   [-1.3457037e+00  2.1614358e+00 -5.1890165e-01 ...
# 7920   [-1.9909439  -0.46401983 -1.6327851   0.249815...
# 8640   [-0.79313356 -1.1117923   0.67747325  0.375749...
# 9595   [-0.32032704 -0.3053469   0.1711486   0.056880...
# 10113  [-0.52172184 -0.40796307  0.36452484 -0.087870...
# 10563  [ 1.8345319   1.3923978  -2.0842724   1.114011...
# 11215  [-0.17797542 -0.09008155 -0.4116054  -0.388270...
# 11917  [-3.38885379e+00 -2.13289738e+00 -2.47612500e+...
# 12664  [-5.2407759e-01  3.4081852e-01 -1.4421235e+00 ...
# 13167  [-1.00938     2.1228166  -0.35689583 -0.837644...
# 13977  [-0.04798649 -2.2460105  -0.89856786 -0.292949...
# 15647  [-1.4400227  -0.22847159 -0.9602066  -0.272610...
# 16710  [-1.1970165  -1.8772913  -2.7874103   2.143194...
